# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
from datetime import datetime
from itertools import chain
import IPython.display
import matplotlib.pyplot as plt

# %%
def open_time(time_path):
    time_list = []
    with open(time_path, 'r') as file:
        for line in file:
            time_list.append(line.strip())
        print(time_list)
    return time_list


 
# df HIP100587 B 
#df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-11/results/results_2023-09-11_df_HIP100587_unfocused_B (Johnson)_4.0s.csv')
#times1 = open_time('/home/finn/visual_Studio_Code/data/2023-09-11/results/time_list_2023-09-11_df_HIP100587_unfocused_B (Johnson)_4.0s.txt')
#df2 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-26/results/results_2023-09-26_df_HIP100587_defocused_B (Johnson)_4.0s_rgaia=8.csv')
#times2 = open_time('/home/finn/visual_Studio_Code/data/2023-09-26/results/time_list_2023-09-26_df_HIP100587_defocused_B (Johnson)_4.0s.txt')


# df HIP100587 R
#/home/finn/visual_Studio_Code/data/2023-09-11/results/results_2023-09-11_df_HIP100587_unfocused_R (Johnson)_0.5s_brightest=75(39)
#df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-11/results/results_2023-09-11_df_HIP100587_unfocused_R (Johnson)_0.5s_n_top85_rgaia=8.csv')
#times1 = open_time('/home/finn/visual_Studio_Code/data/2023-09-11/results/time_list_2023-09-11_df_HIP100587_unfocused_R (Johnson)_0.5s.txt')
#df2 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-26/results/results_2023-09-26_df_HIP100587_defocused_R (Johnson)_1.5s_rgaia=8.csv')
#times2 = open_time('/home/finn/visual_Studio_Code/data/2023-09-26/results/time_list_2023-09-26_df_HIP100587_defocused_R (Johnson)_1.5s.txt')

# df HIP75458
#df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-30/results/results_2023-09-30_df_HIP75458_B (Johnson)_3.0s_30stacked.csv')   
#times1 = open_time('/home/finn/visual_Studio_Code/data/2023-09-30/results/time_list_2023-09-30_df_HIP75458_B (Johnson)_3.0s_30stacked.txt')
#df2 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-10-01/results/results_2023-10-01_df_HIP75458_defocused2_B (Johnson)_1.5s_30stacked.csv')
#times2 = open_time('/home/finn/visual_Studio_Code/data/2023-10-01/results/time_list_2023-10-01_df_HIP75458_B (Johnson)_1.5s_30_stacked.txt')

#mesh 
#df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-26/results/results_2023-09-26_ms_HIP100587_mesh_series_R (Johnson)_5.0s_ref_stars.csv')
#df2 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-26/results/results_2023-09-26_ms_HIP100587_mesh_series_R (Johnson)_5.0s_target_star.csv')
#times1 = open_time('/home/finn/visual_Studio_Code/data/2023-09-26/results/time_list_2023-09-26_ms_HIP100587_mesh_series_R (Johnson)_5.0s.txt')

#df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-30/results/results_2023-09-30_ms_HIP75458_B (Johnson)_14.0s_ref_stars.csv')
#df2 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-30/results/results_2023-09-30_ms_HIP75458_B (Johnson)_14.0s_target_star.csv')
#times1= open_time('/home/finn/visual_Studio_Code/data/2023-09-30/results/time_list_2023-09-30_ms_HIP75458_B (Johnson)_14.0s.txt')

#df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-30/results/results_2023-09-30_ms_HIP100587_mesh_B (Johnson)_30.0s_ref_stars.csv')
#df2 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-30/results/results_2023-09-30_ms_HIP100587_mesh_B (Johnson)_30.0s_target_star.csv')
#times1 = open_time('/home/finn/visual_Studio_Code/data/2023-09-30/results/time_list_2023-09-30_ms_HIP100587_mesh_B (Johnson)_30.0s.txt')

#df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-09/results/results_2024-01-09_df_HIP100587_df_B_5_B (Johnson)_5.0s.csv')
#df2 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-10/results/results_2024-01-10_df_HIP100587_df_B_7s_B (Johnson)_7.0s.csv')
#df3 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-11/results/results_2024-01-11_df_HIP100587_df_B_8s_B (Johnson)_8.0s.csv')
#t1 = open_time('/home/finn/visual_Studio_Code/data/2024-01-09/results/time_list_2024-01-09_df_HIP100587_df_B_5_B (Johnson)_5.0s.txt')
#t2 = open_time('/home/finn/visual_Studio_Code/data/2024-01-10/results/time_list_2024-01-10_df_HIP100587_df_B_7s_B (Johnson)_7.0s.txt')
#t3 = open_time('/home/finn/visual_Studio_Code/data/2024-01-11/results/time_list_2024-01-11_df_HIP100587_df_B_8s_B (Johnson)_8.0s.txt')

#For CMD
#df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-10/results/results_2024-01-10_HIP102488_ref_30s_R (Johnson)_30.0s_10_images_stacked_0.csv')
#t1 = open_time('/home/finn/visual_Studio_Code/data/2024-01-10/results/time_list_2024-01-10_ls_HIP102488_ref_30s_R (Johnson).txt')
#df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-25/results/results_2023-09-25_HIP100587_B (Johnson)_40.0s_10_images_stacked_0_r_gaia=5.csv')
#t1 = open_time('/home/finn/visual_Studio_Code/data/2023-09-25/results/time_list.txt')

# Time series ls
'''df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-04/results/results_2023-09-04_HIP_100587_B (Johnson)_30new_2.5arcsec.csv')
df2 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-11/results/results_2023-09-11_HIP100587_focused_B (Johnson)_40new_2.5arcsec')
df3 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-25/results/results_2023-09-25_HIP100587_B (Johnson)_40.0s_10_images_stacked_0_r_gaia=5.csv')
t1 = open_time('/home/finn/visual_Studio_Code/data/2023-09-04/results/time_list.txt')
t2 = open_time('/home/finn/visual_Studio_Code/data/2023-09-11/results/time_list_2023-09-11_ls_HIP100587_focused_B (Johnson).txt')
t3 = open_time('/home/finn/visual_Studio_Code/data/2023-09-25/results/time_list_2023-09-25_ls_HIP100587_B (Johnson).txt')'''

# Time series df
'''df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-30/results/results_2023-09-30_df_HIP75458_B (Johnson)_3.0s_30stacked.csv')
df2 = pd.read_csv('/home/finn/visual_Studio_Code/data/2023-10-01/results/results_2023-10-01_df_HIP75458_defocused2_B (Johnson)_1.5s_30stacked.csv')
df3 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-10/results/results_2024-01-11_df_HIP75458_df_B_3s_B (Johnson)_3.0s.csv')
df4 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-11/results/results_2024-01-12_df_HIP75458_df_B_3_5s_B (Johnson)_3.5s.csv')
t1 = open_time('/home/finn/visual_Studio_Code/data/2023-09-30/results/time_list_2023-09-30_df_HIP75458_B (Johnson)_3.0s_30stacked.txt')
t2 = open_time('/home/finn/visual_Studio_Code/data/2023-10-01/results/time_list_2023-10-01_df_HIP75458_B (Johnson)_1.5s_30_stacked.txt')
t3 = open_time('/home/finn/visual_Studio_Code/data/2024-01-10/results/time_list_2024-01-11_df_HIP75458_df_B_3s_B (Johnson)_3.0s.txt')
t4 = open_time('/home/finn/visual_Studio_Code/data/2024-01-11/results/time_list_2024-01-12_df_HIP75458_df_B_3_5s_B (Johnson)_3.5s.txt')'''

# Time series ms hip75458
'''df1=pd.read_csv('/home/finn/visual_Studio_Code/data/2023-10-01/results/results_2023-10-01_ms_HIP75458_mesh_R (Johnson)_15.0s_ref_stars_with_coord.csv')
df2=pd.read_csv('/home/finn/visual_Studio_Code/data/2023-10-01/results/results_2023-10-01_ms_HIP75458_mesh_R (Johnson)_15.0s_target_star_with_coord.csv')
df3=pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-10/results/results_2024-01-11_ms_HIP75458_ms_R_45s_R (Johnson)_45.0s_ref_stars_with_coord.csv')
df4=pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-10/results/results_2024-01-11_ms_HIP75458_ms_R_45s_R (Johnson)_45.0s_target_star_with_coord.csv')
df5=pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-11/results/results_2024-01-11_ms_HIP75458_ms_R_42s_R (Johnson)_42.0s_ref_stars_with_coord.csv')
df6=pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-11/results/results_2024-01-11_ms_HIP75458_ms_R_42s_R (Johnson)_42.0s_target_star_with_coord.csv')
t1 = open_time('/home/finn/visual_Studio_Code/data/2023-10-01/results/time_list_2023-10-01_ms_HIP75458_mesh_R (Johnson)_15.0s.txt')
t2 = open_time('/home/finn/visual_Studio_Code/data/2024-01-10/results/time_list_2024-01-11_ms_HIP75458_ms_R_45s_R (Johnson)_45.0s.txt')
t3 = open_time('/home/finn/visual_Studio_Code/data/2024-01-11/results/time_list_2024-01-11_ms_HIP75458_ms_R_42s_R (Johnson)_42.0s.txt')'''
#df2 = df2.drop([14,15,21,25])


# ts ms hip100587 09-01-24
'''df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-09/results/results_2024-01-09_ms_HIP100587_ms_R_30s_R (Johnson)_30.0s_ref_stars.csv')
df2 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-09/results/results_2024-01-09_ms_HIP100587_ms_R_30s_R (Johnson)_30.0s_target_star.csv')
df3 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-10/results/results_2024-01-10_ms_HIP100587_ms_R_35s_R (Johnson)_35.0s_ref_stars.csv')
df4 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-10/results/results_2024-01-10_ms_HIP100587_ms_R_35s_R (Johnson)_35.0s_target_star.csv')
df5 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-11/results/results_2024-01-11_ms_HIP100587_ms_R_35_R (Johnson)_35.0s_ref_stars.csv')
df6 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-11/results/results_2024-01-11_ms_HIP100587_ms_R_35_R (Johnson)_35.0s_target_star.csv')
t1 = open_time('/home/finn/visual_Studio_Code/data/2024-01-09/results/time_list_2024-01-09_ms_HIP100587_ms_R_30s_R (Johnson)_30.0s.txt')
t2 = open_time('/home/finn/visual_Studio_Code/data/2024-01-10/results/time_list_2024-01-10_ms_HIP100587_ms_R_35s_R (Johnson)_35.0s.txt')
t3 = open_time('/home/finn/visual_Studio_Code/data/2024-01-11/results/time_list_2024-01-11_ms_HIP100587_ms_R_35_R (Johnson)_35.0s.txt')'''

# ts df hip100587 09-01-24
df1 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-09/results/results_2024-01-09_df_HIP100587_df_B_5_B (Johnson)_5.0s.csv')
df2 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-10/results/results_2024-01-10_df_HIP100587_df_B_7s_B (Johnson)_7.0s.csv')
df3 = pd.read_csv('/home/finn/visual_Studio_Code/data/2024-01-11/results/results_2024-01-11_df_HIP100587_df_B_8s_B (Johnson)_8.0s.csv')
t1 = open_time('/home/finn/visual_Studio_Code/data/2024-01-09/results/time_list_2024-01-09_df_HIP100587_df_B_5_B (Johnson)_5.0s.txt')
t2 = open_time('/home/finn/visual_Studio_Code/data/2024-01-10/results/time_list_2024-01-10_df_HIP100587_df_B_7s_B (Johnson)_7.0s.txt')
t3 = open_time('/home/finn/visual_Studio_Code/data/2024-01-11/results/time_list_2024-01-11_df_HIP100587_df_B_8s_B (Johnson)_8.0s.txt')


target = 'HIP 100587' #for plot title later !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1
filter_list = ['R'] #too !!!!!!!!!!!!!!!!!
series_type = 'defocused' # too !!!!!!!!!!!!!!!!!!!!!!!

time_list = [t1,t2,t3] #change here

'''dfs_ft = [df1, df3, df5]
dfs_br = [df2, df4, df6]
for df in dfs_ft:
    print(len(df))
    display(df.head())
for df in dfs_br:
    print(len(df))
    display(df)
'''

df_list = [df1, df2, df3]
for df in df_list:
    print(len(df))
    display(df.head())

def shorten_time(time_list):
    datetime_objects = [datetime.strptime(ts, '%Y-%m-%dT%H:%M:%S') for ts in time_list]
    shortened_timestamps = [dt.strftime('%m-%d %H:%M') for dt in datetime_objects]
    return shortened_timestamps
short_times = [shorten_time(t) for t in time_list] # shorten timestamps for better readibily of the plot
# Out:
# ['2024-01-09T18:30:55', '2024-01-09T18:34:02', '2024-01-09T18:37:09', '2024-01-09T18:40:16', '2024-01-09T18:43:24', '2024-01-09T18:46:31', '2024-01-09T18:49:38', '2024-01-09T18:52:44', '2024-01-09T18:55:51', '2024-01-09T18:58:58']
# ['2024-01-10T18:33:08', '2024-01-10T18:36:46', '2024-01-10T18:40:24', '2024-01-10T18:44:01', '2024-01-10T18:47:38', '2024-01-10T18:51:14', '2024-01-10T18:54:51']
# ['2024-01-11T18:32:35', '2024-01-11T18:35:11', '2024-01-11T18:37:46', '2024-01-11T18:40:21', '2024-01-11T18:42:57', '2024-01-11T18:45:32', '2024-01-11T18:48:08', '2024-01-11T18:50:43', '2024-01-11T18:52:47']
# 56
#    Unnamed: 0                       DR3Name     RAJ2000    DEJ2000     BPmag  \
# 0           0  Gaia DR3 1862199005254756736  306.139069  32.207997  9.239444
# 1           1  Gaia DR3 1862187907058841088  306.133825  32.016689  9.365703
# 2           2  Gaia DR3 1862190861985484800  306.013421  32.092404  9.214108
# ...

# %%
'''tolerance = 80/3600 # 1/3600 = arcsec
print(tolerance)
def filter_dataframe(df, other_dfs):

        return df[df.apply(lambda row: 
                        all(any(((other_df['RAJ2000'] - row['RAJ2000']).abs() <= tolerance) & ((other_df['DEJ2000'] - row['DEJ2000']).abs() <= tolerance)) #any means if at least one cond. = True, all if all cond. are true
                        for other_df in other_dfs), axis=1)]

    # Filter each DataFrame in df_list
#fil_dfs_ft = [filter_dataframe(df, [other_df for other_df in dfs_ft if other_df is not df]) for df in dfs_ft]
#fil_dfs_br = [filter_dataframe(df, [other_df for other_df in dfs_br if other_df is not df]) for df in dfs_br]
fil_dfs_ft = dfs_ft
fil_dfs_br = dfs_br

for df in fil_dfs_ft:
    print(len(df))
    display(df.head())

for df in fil_dfs_br:
    print(len(df))
    display(df.head())'''
# Out:
# "tolerance = 80/3600 # 1/3600 = arcsec\nprint(tolerance)\ndef filter_dataframe(df, other_dfs):\n\n        return df[df.apply(lambda row: \n                        all(any(((other_df['RAJ2000'] - row['RAJ2000']).abs() <= tolerance) & ((other_df['DEJ2000'] - row['DEJ2000']).abs() <= tolerance)) #any means if at least one cond. = True, all if all cond. are true\n                        for other_df in other_dfs), axis=1)]\n\n    # Filter each DataFrame in df_list\n#fil_dfs_ft = [filter_dataframe(df, [other_df for other_df in dfs_ft if other_df is not df]) for df in dfs_ft]\n#fil_dfs_br = [filter_dataframe(df, [other_df for other_df in dfs_br if other_df is not df]) for df in dfs_br]\nfil_dfs_ft = dfs_ft\nfil_dfs_br = dfs_br\n\nfor df in fil_dfs_ft:\n    print(len(df))\n    display(df.head())\n\nfor df in fil_dfs_br:\n    print(len(df))\n    display(df.head())"

# %%
'''#alternative filter approach by using same x and y positions
if  any('DR3Name' not in df.columns for df in df_list) and series_type != 'mesh':
    x_list,y_list = [], []
    for i in range (len(df_list)):
        x_br = df_list[i]['x'].iloc[-1]
        x_list.append(x_br)
        y_br = df_list[i]['y'].iloc[-1]
        y_list.append(y_br)

    #print(x_list, y_list)


    x_shift, y_shift = [], []
    for j in range (1, len(x_list)):
        print(j)
        x_shift.append(x_list[0] - x_list[j])
        y_shift.append(y_list[0] - y_list[j])

    #print(x_shift, y_shift)

    for i in range (1, len (df_list)):
        df_list[i]['x'] = df_list[i]['x'] + x_shift[i-1]
        df_list[i]['y'] = df_list[i]['y'] + y_shift[i-1]
        print(df_list[i]['x'].tail())

    tolerance = 15

    # Function to filter rows based on tolerance
    def filter_dataframe(df, other_dfs):
        return df[df.apply(lambda row: all(
            any(((other_df['x'] - row['x']).abs() <= tolerance) & ((other_df['y'] - row['y']).abs() <= tolerance)) 
            for other_df in other_dfs), axis=1)]

    # Filter each DataFrame in df_list
    df_list = [filter_dataframe(df, [other_df for other_df in df_list if other_df is not df]) for df in df_list]

    # Print the filtered DataFrames
    for df in df_list:
        #print(f"\nFiltered DataFrame {i}:")
        display(df)
else:
    print('skip this step and fiter by gaia coord.')'''
# Out:
# '#alternative filter approach by using same x and y positions\nif  any(\'DR3Name\' not in df.columns for df in df_list) and series_type != \'mesh\':\n    x_list,y_list = [], []\n    for i in range (len(df_list)):\n        x_br = df_list[i][\'x\'].iloc[-1]\n        x_list.append(x_br)\n        y_br = df_list[i][\'y\'].iloc[-1]\n        y_list.append(y_br)\n\n    #print(x_list, y_list)\n\n\n    x_shift, y_shift = [], []\n    for j in range (1, len(x_list)):\n        print(j)\n        x_shift.append(x_list[0] - x_list[j])\n        y_shift.append(y_list[0] - y_list[j])\n\n    #print(x_shift, y_shift)\n\n    for i in range (1, len (df_list)):\n        df_list[i][\'x\'] = df_list[i][\'x\'] + x_shift[i-1]\n        df_list[i][\'y\'] = df_list[i][\'y\'] + y_shift[i-1]\n        print(df_list[i][\'x\'].tail())\n\n    tolerance = 15\n\n    # Function to filter rows based on tolerance\n    def filter_dataframe(df, other_dfs):\n        return df[df.apply(lambda row: all(\n            any(((other_d
# ...

# %%
'''df1['Mean_Mag'] = df1[['Mag_Mean_Im_1', 'Mag_Mean_Im_2', 'Mag_Mean_Im_3', 'Mag_Mean_Im_4', 'Mag_Mean_Im_5']].mean(axis=1)
df2['Mean_Mag'] = df2[['Mag_Mean_Im_1', 'Magmag_median_br_list
y_diff = df1['y'][5]- df2['y'][6]

df2['x'] = df2['x']+x_diff
df2['y'] = df2['y']+y_diff

df2 = df2.drop(4)

display(df1)
display(df2)'''
# Out:
# "df1['Mean_Mag'] = df1[['Mag_Mean_Im_1', 'Mag_Mean_Im_2', 'Mag_Mean_Im_3', 'Mag_Mean_Im_4', 'Mag_Mean_Im_5']].mean(axis=1)\ndf2['Mean_Mag'] = df2[['Mag_Mean_Im_1', 'Magmag_median_br_list\ny_diff = df1['y'][5]- df2['y'][6]\n\ndf2['x'] = df2['x']+x_diff\ndf2['y'] = df2['y']+y_diff\n\ndf2 = df2.drop(4)\n\ndisplay(df1)\ndisplay(df2)"

# %%
def filter_common_names(df_list):

    if any('DR3Name' not in df.columns for df in df_list):
            filtered_df = df_list.copy()
            print('no gaia names in dfs')
            return filtered_df
    else: 
        if isinstance(df_list, pd.DataFrame):  # Check if df_list is a single DataFrame
            filtered_df = df_list.copy()
            filtered_df['absolute Gmag'] = filtered_df['Gmag'] + 5 * np.log10(filtered_df['Plx'] / 100)
            print('success for single frame')
            return filtered_df
        else:  # For multiple DataFrames in the list
            unique_names_list = [df['DR3Name'].unique() for df in df_list]
            common_names = set(unique_names_list[0]).intersection(*unique_names_list[1:])
            filtered_dfs = [df[df['DR3Name'].isin(common_names)].copy() for df in df_list]
            for df in filtered_dfs:
                df['absolute Gmag'] = df['Gmag'] + 5 * np.log10(df['Plx'] / 100)
            print('success for multiple frames')
            return filtered_dfs


fil_dfs = filter_common_names(df_list)
for i, df in enumerate(fil_dfs):
    print(f"Filtered DataFrame {i+1}:")
    print(len(df))
    #display(df)
# Out:
# success for multiple frames
# Filtered DataFrame 1:
# 38
# Filtered DataFrame 2:
# 38
# Filtered DataFrame 3:
# 38

# %%
'''df_plot = fil_dfs[0] # change if you want to use filtered data for plotting

if not any('DR3Name' not in df.columns for df in fil_dfs):
    #import cns5 data for comparrison
    df_cns5 = pd.read_csv('/home/finn/visual_Studio_Code/data/CNS5_data.csv')
    df_cns5 = df_cns5.dropna() # remove all NaN values
    df_cns5['absolute Gmag CNS5'] = df_cns5['g_mag'] + 5*np.log10(df_cns5['parallax']/100)

    fig, axs = plt.subplots(1, 2, figsize=(15, 6))

    axs[0].scatter(df_plot['G-RP'], df_plot['absolute Gmag'], alpha=0.5,s=15, label=f'Stars FOV {target}')
    axs[0].scatter(df_plot['G-RP'][-1:], df_plot['absolute Gmag'][-1:], alpha=0.5, color='purple', label=target)
    axs[0].scatter(df_cns5['g_rp_resulting'], df_cns5['absolute Gmag CNS5'], alpha=0.2, color='red', s=1,label='CNS5 stars')
    axs[0].invert_yaxis()  
    axs[0].set_xlabel('G-RP [mag]')
    axs[0].set_ylabel(r'$M_G$ [mag]')
    axs[0].legend()
    axs[0].set_title(f'Color-Magnitude diagram for the field of {target} (with {len(df_plot)-1} detected stars)')

    axs[1].scatter(df_plot['BP-RP'][:-1], df_plot['absolute Gmag'][:-1], alpha=0.5,   s=20.0,label=f'Stars FOV {target}')
    axs[1].scatter(df_plot['BP-RP'][-1:], df_plot['absolute Gmag'][-1:], alpha=0.5, color='purple', s=20, label=target)
    axs[1].legend()
    axs[1].invert_yaxis()
    axs[1].set_xlabel('BP-RP [mag]')
    axs[1].set_ylabel(r'$M_G$ [mag]')

    plt.tight_layout()
else:
    print('No Gaia positions in df')'''
# Out:
# "df_plot = fil_dfs[0] # change if you want to use filtered data for plotting\n\nif not any('DR3Name' not in df.columns for df in fil_dfs):\n    #import cns5 data for comparrison\n    df_cns5 = pd.read_csv('/home/finn/visual_Studio_Code/data/CNS5_data.csv')\n    df_cns5 = df_cns5.dropna() # remove all NaN values\n    df_cns5['absolute Gmag CNS5'] = df_cns5['g_mag'] + 5*np.log10(df_cns5['parallax']/100)\n\n    fig, axs = plt.subplots(1, 2, figsize=(15, 6))\n\n    axs[0].scatter(df_plot['G-RP'], df_plot['absolute Gmag'], alpha=0.5,s=15, label=f'Stars FOV {target}')\n    axs[0].scatter(df_plot['G-RP'][-1:], df_plot['absolute Gmag'][-1:], alpha=0.5, color='purple', label=target)\n    axs[0].scatter(df_cns5['g_rp_resulting'], df_cns5['absolute Gmag CNS5'], alpha=0.2, color='red', s=1,label='CNS5 stars')\n    axs[0].invert_yaxis()  \n    axs[0].set_xlabel('G-RP [mag]')\n    axs[0].set_ylabel(r'$M_G$ [mag]')\n    axs[0].legend()\n    axs[0].set_title(f'Color-Magnitude diagram for the field o
# ...

# %%
print(series_type)
# Out:
# defocused

# %%
def get_mag_lists(df):
    df_ft = df.iloc[:-1,:] # all rows expept last one (bright star), all columns
    #display(df_ft)
    df_br = df.iloc[-1:,:] #just last row
    #display(df_br)

    mag_mean_columns_ft = [col for col in df_ft.columns if 'Mag_Mean_Im' in col]
    mag_mean_ft = df_ft[mag_mean_columns_ft].values.T.tolist()
    mean_mag_mean_ft = [np.mean(sublist) for sublist in mag_mean_ft]

    mag_median_columns_ft = [col for col in df_ft.columns if 'Mag_Median_Im' in col]
    mag_median_ft = df_ft[mag_median_columns_ft].values.T.tolist()
    mean_mag_median_ft = [np.mean(sublist) for sublist in mag_median_ft]

    mag_mean_columns_br = [col for col in df_br.columns if 'Mag_Mean_Im' in col]
    mag_mean_br = df_br[mag_mean_columns_br].values.T.tolist() 
    mag_mean_br = list(chain.from_iterable(mag_mean_br)) #to remove inner brackets i.e. [[.],[.],[.]] -> [.,.,.]

    mag_median_columns_br = [col for col in df_br.columns if 'Mag_Median_Im' in col]
    mag_median_br = df_br[mag_median_columns_br].values.T.tolist()
    mag_median_br = list(chain.from_iterable(mag_median_br))

    print(mean_mag_mean_ft)
    print(mean_mag_median_ft)
    print(mag_mean_br)
    print(mag_median_br)
    print('')
    return mean_mag_mean_ft, mean_mag_median_ft, mag_mean_br, mag_median_br



def get_mag_lists_mesh(df_ft, df_br):

    mag_mean_columns_ft = [col for col in df_ft.columns if 'Mag_Mean_Im' in col]
    mag_mean_ft = df_ft[mag_mean_columns_ft].values.T.tolist()
    mean_mag_mean_ft = [np.mean(sublist) for sublist in mag_mean_ft]

    mag_median_columns_ft = [col for col in df_ft.columns if 'Mag_Median_Im' in col]
    mag_median_ft = df_ft[mag_median_columns_ft].values.T.tolist()
    mean_mag_median_ft = [np.mean(sublist) for sublist in mag_median_ft]

    mag_mean_columns_br = [col for col in df_br.columns if 'Mag_Mean_Im' in col]
    mag_mean_br = df_br[mag_mean_columns_br].values.T.tolist() 
    #mag_mean_br = list(chain.from_iterable(mag_mean_br)) #to remove inner brackets i.e. [[.],[.],[.]] -> [.,.,.]
    mag_mean_br = [np.mean(sublist) for sublist in mag_mean_br]

    mag_median_columns_br = [col for col in df_br.columns if 'Mag_Median_Im' in col]
    mag_median_br = df_br[mag_median_columns_br].values.T.tolist()
    #mag_median_br = list(chain.from_iterable(mag_median_br))
    mag_median_br = [np.mean(sublist) for sublist in mag_median_br]

    print(mean_mag_mean_ft)
    print(mean_mag_median_ft)
    print(mag_mean_br)
    print(mag_median_br)
    print('')
    return mean_mag_mean_ft, mean_mag_median_ft, mag_mean_br, mag_median_br


mean_mag_mean_ft_list = []
mean_mag_median_ft_list = []
mag_mean_br_list = []
mag_median_br_list = []

if series_type != 'mesh':
    print('no mesh')
    for df in fil_dfs:
        mean_mag_mean_ft, mean_mag_median_ft, mag_mean_br, mag_median_br = get_mag_lists(df)
        mean_mag_mean_ft_list.append(mean_mag_mean_ft)
        mean_mag_median_ft_list.append(mean_mag_median_ft)
        mag_mean_br_list.append(mag_mean_br)
        mag_median_br_list.append(mag_median_br)

else: 
    print('mesh')
    for i in range (len(time_list)):
        mean_mag_mean_ft, mean_mag_median_ft, mag_mean_br, mag_median_br = get_mag_lists_mesh(fil_dfs_ft[i], fil_dfs_br[i]) 
        mean_mag_mean_ft_list.append(mean_mag_mean_ft)
        mean_mag_median_ft_list.append(mean_mag_median_ft)
        mag_mean_br_list.append(mag_mean_br)
        mag_median_br_list.append(mag_median_br)
# Out:
# no mesh
# [-7.736574946956317, -7.728601766601511, -7.707528728785728, -7.715718191095223, -7.695856013556282, -7.700160130137522, -7.643847799664987, -7.64315335318174, -7.644650934220968, -7.61364012757857]
# [-7.729587047524324, -7.721834846405746, -7.700843361085837, -7.702897055291854, -7.690085532119272, -7.699112963723305, -7.645737276755224, -7.641431345108382, -7.6362181337097885, -7.61149601384482]
# [-15.07374826666825, -15.073693413159354, -15.059142719562605, -15.042634876456171, -15.029629899338142, -15.00616787683297, -15.003302861852807, -14.996475857606768, -14.963772235415693, -14.958937276994993]
# [-15.06182562762528, -15.072429700584491, -15.055933924121474, -15.038004094575816, -15.020510785226303, -15.001012113524128, -14.994458471298934, -14.995590929608596, -14.958580720265688, -14.948086722698909]
#
# [-7.621744886456045, -7.627423737775155, -7.575077968224187, -7.577531464884003, -7.555929871823334, -7.528972732878009, -7.492264212728588]
# ...

# %%
# ONLY FOR 25.09 HIP100587 ls B
'''
mean_mag_mean_ft3 = mean_mag_mean_ft3[1:]
mean_mag_median_ft3 = mean_mag_median_ft3[1:]
mag_mean_br3 = mag_mean_br3[1:]
mag_median_br3 = mag_median_br3[1:]
'''
# Out:
# '\nmean_mag_mean_ft3 = mean_mag_mean_ft3[1:]\nmean_mag_median_ft3 = mean_mag_median_ft3[1:]\nmag_mean_br3 = mag_mean_br3[1:]\nmag_median_br3 = mag_median_br3[1:]\n'

# %%
print(mean_mag_mean_ft_list)
print(mag_mean_br_list)
print(mean_mag_mean_ft_list[0])
print(mag_mean_br_list[0])
print(time_list[0])
# Out:
# [[-7.736574946956317, -7.728601766601511, -7.707528728785728, -7.715718191095223, -7.695856013556282, -7.700160130137522, -7.643847799664987, -7.64315335318174, -7.644650934220968, -7.61364012757857], [-7.621744886456045, -7.627423737775155, -7.575077968224187, -7.577531464884003, -7.555929871823334, -7.528972732878009, -7.492264212728588], [-7.7402929210778355, -7.71551251616105, -7.707668202769859, -7.707779830162428, -7.6826658009690325, -7.665121547741234, -7.645165134086226, -7.652130814917602, -7.616188592861188]]
# ...

# %%
def calc_results(mag_ft_mean, mag_br_mean, mag_ft_median, mag_br_median):
    diff_mags_mean = [m_br - m_ft for m_br, m_ft in zip(mag_br_mean, mag_ft_mean)]
    diff_mags_median = [m_br - m_ft for m_br, m_ft in zip(mag_br_median, mag_ft_median)]
    print(f'The diff Mag (mean stacked) is:   M = ${round(np.mean(diff_mags_mean), 5)}\pm{round(np.std(diff_mags_mean), 5)}$')
    print(f'The diff Mag (median stacked) is: M = ${round(np.mean(diff_mags_median), 5)}\pm{round(np.std(diff_mags_median), 5)}$')
    print('')
    #print(f'The std for target (mean stacked):   {round(np.std(mag_br_mean), 5)} and for the bkg stars (mean values):    {round(np.std(mag_ft_mean), 5)}')
    #print(f'The std for target (median stacked): {round(np.std(mag_br_median), 5)} and for the bkg stars (median stacked): {round(np.std(mag_ft_median), 5)}')
    return diff_mags_mean, diff_mags_median


diff_mags_mean_list = []
diff_mags_median_list = []
for i in range(len(mean_mag_mean_ft_list)):
    print(f'for df{i+1}:')
    diff_mags_mean, diff_mags_median = calc_results(mean_mag_mean_ft_list[i], mag_mean_br_list[i], mean_mag_median_ft_list[i], mag_median_br_list[i])                                      
    diff_mags_mean_list.append(diff_mags_mean)
    diff_mags_median_list.append(diff_mags_median)
# Out:
# for df1:
# The diff Mag (mean stacked) is:   M = $-7.33778\pm0.01583$
# The diff Mag (median stacked) is: M = $-7.33672\pm0.01568$
#
# for df2:
# The diff Mag (mean stacked) is:   M = $-7.3688\pm0.0144$
# The diff Mag (median stacked) is: M = $-7.36244\pm0.01435$
#
# for df3:
# The diff Mag (mean stacked) is:   M = $-7.37685\pm0.01102$
# The diff Mag (median stacked) is: M = $-7.37499\pm0.01222$

# %%
# JUST for ls Hip100587 B remove later !!!!!!!!!!!!!!!!!!!!!!!!!!!!
'''diff_mags_mean_list = [diff_mags_mean_list[0], diff_mags_mean_list[1], diff_mags_mean_list[2][1:]]
diff_mags_median_list = [diff_mags_median_list[0], diff_mags_median_list[1], diff_mags_median_list[2][1:]]
mean_mag_mean_ft_list = [mean_mag_mean_ft_list[0], mean_mag_mean_ft_list[1], mean_mag_mean_ft_list[2][1:]]
mag_mean_br_list = [mag_mean_br_list[0], mag_mean_br_list[1], mag_mean_br_list[2][1:]]
short_times = [short_times[0], short_times[1], short_times[2][1:]]
print(len(diff_mags_mean_list[2]), len(short_times[2]))
print(f'${round(np.mean(diff_mags_mean_list[2]),4)}\pm{round(np.std(diff_mags_mean_list[2]),4)}')
print(f'${round(np.mean(diff_mags_median_list[2]),4)}\pm{round(np.std(diff_mags_median_list[2]),4)}')'''
# Out:
# "diff_mags_mean_list = [diff_mags_mean_list[0], diff_mags_mean_list[1], diff_mags_mean_list[2][1:]]\ndiff_mags_median_list = [diff_mags_median_list[0], diff_mags_median_list[1], diff_mags_median_list[2][1:]]\nmean_mag_mean_ft_list = [mean_mag_mean_ft_list[0], mean_mag_mean_ft_list[1], mean_mag_mean_ft_list[2][1:]]\nmag_mean_br_list = [mag_mean_br_list[0], mag_mean_br_list[1], mag_mean_br_list[2][1:]]\nshort_times = [short_times[0], short_times[1], short_times[2][1:]]\nprint(len(diff_mags_mean_list[2]), len(short_times[2]))\nprint(f'${round(np.mean(diff_mags_mean_list[2]),4)}\\pm{round(np.std(diff_mags_mean_list[2]),4)}')\nprint(f'${round(np.mean(diff_mags_median_list[2]),4)}\\pm{round(np.std(diff_mags_median_list[2]),4)}')"

# %%
def plot_ts(input_list, plot_mean=False):
    
    length = len(short_times) 
    fig, ax = plt.subplots(1, len(short_times), sharey=True, facecolor='w', figsize = (14,7))
    ax[0].set_ylabel('Magnitudes [mag]', fontsize=16)
    ax[length//2].set_xlabel('Time [month-day hour:minute]', fontsize=16)
    for i in range(length):
        if i < 0: # just for cases with multiple years
            for j in range(length):
                    ax[j].errorbar(short_times[i], input_list[i], yerr=np.std(input_list[i]), linestyle='none', marker='o', 
                                    label='Series (2023-' + short_times[i][0][:5] +')', capsize=3)
        else: 
             for j in range(length):
                    ax[j].errorbar(short_times[i], input_list[i], yerr=np.std(input_list[i]), linestyle='none', marker='o', 
                                    label='Series (2024-' + short_times[i][0][:5] +')', capsize=3)
        ax[i].tick_params(axis='x', rotation=45)
        ax[i].tick_params(axis='both', which='both', labelsize=14)

        buffer = 0.5
        ax[i].set_xlim(short_times[i][0], short_times[i][-1])
        ax[i].set_xlim(ax[i].get_xlim()[0] - buffer, ax[i].get_xlim()[1] + buffer)


        if i > 0:
            ax[i].spines['left'].set_visible(False)
            ax[i].tick_params(left=False, right=False)  # Remove ticks in the middle subplot

        d = .015  # how big to make the diagonal lines in axes coordinates  
        if i < length - 1:
            ax[i].spines['right'].set_visible(False)
            kwargs = dict(transform=ax[i].transAxes, color='k', clip_on=False)
            ax[i].plot((1-d, 1+d), (-d, +d), **kwargs)        # top-left diagonal
            ax[i].plot((1-d, 1+d), (1-d, 1+d), **kwargs)
            kwargs.update(transform=ax[i+1].transAxes)
            ax[i+1].plot((-d, +d), (1-d, 1+d), **kwargs)  # bottom-left diagonal
            ax[i+1].plot(( - d, + d), (- d,  + d), **kwargs)        # bottom-left diagonal

        means_mean_stacked = [np.mean(m) for m in input_list]
        print(f'The mean of all {length} series is: {round(np.mean(means_mean_stacked),4)} with std. of: {round(np.std(means_mean_stacked),4)}')
        if plot_mean == True:         
            ax[i].axhline(np.mean(means_mean_stacked), label=f'mean of all series', color='black', linestyle='--', alpha=0.5)
    
    ax[length-1].legend(fontsize=16)
    fig.subplots_adjust(hspace=0.5)
    plt.tight_layout()

# %%
#mean stacked
#title = f'Time series of differential magnitudes for {target} in "{series_type} method" with {filter_list[0]} filter'
plot_ts(diff_mags_mean_list,  plot_mean=False)
plt.savefig(f'/home/finn/Pictures/Results Time Series Final/{series_type}_{target}_{filter_list[0][:1]}_diff_mags_mean_stacked.png')

#median stacked
plot_ts(diff_mags_median_list,  plot_mean=False)
plt.savefig(f'/home/finn/Pictures/Results Time Series Final/{series_type}_{target}_{filter_list[0][:1]}_diff_mags_median_stacked.png')
# Out:
# The mean of all 3 series is: -7.3611 with std. of: 0.0168
# The mean of all 3 series is: -7.3611 with std. of: 0.0168
# The mean of all 3 series is: -7.3611 with std. of: 0.0168
# The mean of all 3 series is: -7.358 with std. of: 0.0159
# The mean of all 3 series is: -7.358 with std. of: 0.0159
# The mean of all 3 series is: -7.358 with std. of: 0.0159

# %%
plot_ts(mean_mag_mean_ft_list, plot_mean=False)
#plt.savefig(f'/home/finn/Pictures/Results Time Series Final/{series_type}_{target}_{filter_list[0][:1]}_bkg_mags.png')

plot_ts(mag_mean_br_list)
#plt.savefig(f'/home/finn/Pictures/Results Time Series Final/{series_type}_{target}_{filter_list[0][:1]}_target_mags.png')
# Out:
# The mean of all 3 series is: -7.6443 with std. of: 0.0536
# The mean of all 3 series is: -7.6443 with std. of: 0.0536
# The mean of all 3 series is: -7.6443 with std. of: 0.0536
# The mean of all 3 series is: -15.0054 with std. of: 0.0506
# The mean of all 3 series is: -15.0054 with std. of: 0.0506
# The mean of all 3 series is: -15.0054 with std. of: 0.0506

# %%
def plot_ts2(input_list, ax_nr, plot_mean=False):
    
    ax[ax_nr][0].set_ylabel('Magnitudes [mag]')
    for i in range(length):
        for j in range(length):
            ax[ax_nr][j].errorbar(short_times[i], input_list[i], yerr=np.std(input_list[i]), linestyle='none', marker='o', 
                            label='series from 23-' + short_times[i][0][:5], capsize=2)
        ax[ax_nr][i].tick_params(axis='x', rotation=45)
        ax[ax_nr][i].set_xlabel('Time [month-day hour:minute]')

        buffer = 0.5
        ax[ax_nr][i].set_xlim(short_times[i][0], short_times[i][-1])
        ax[ax_nr][i].set_xlim(ax[ax_nr][i].get_xlim()[0] - buffer, ax[ax_nr][i].get_xlim()[1] + buffer)


        if i > 0:
            ax[ax_nr][i].spines['left'].set_visible(False)
            ax[ax_nr][i].tick_params(left=False, right=False)  # Remove ticks in the middle subplot

        d = .015  # how big to make the diagonal lines in axes coordinates  
        if i < length - 1:
            ax[ax_nr][i].spines['right'].set_visible(False)
            kwargs = dict(transform=ax[ax_nr][i].transAxes, color='k', clip_on=False)
            ax[ax_nr][i].plot((1-d, 1+d), (-d, +d), **kwargs)        # top-left diagonal
            #ax[i].plot((1-d, 1+d), (1-d, 1+d), **kwargs)
            kwargs.update(transform=ax[ax_nr][i+1].transAxes)
            #ax[i+1].plot((-d, +d), (1-d, 1+d), **kwargs)  # bottom-left diagonal
            ax[ax_nr][i+1].plot(( - d, + d), (- d,  + d), **kwargs)        # bottom-left diagonal

        if plot_mean == True:
            means_mean_stacked = [np.mean(diff_mags) for diff_mags in input_list]
            print(f'The mean of all {length} series is: {round(np.mean(means_mean_stacked),4)} with std. of: {round(np.std(means_mean_stacked),4)}')
            ax[ax_nr][i].axhline(np.mean(means_mean_stacked), label=f'mean of all series', color='black', linestyle='--', alpha=0.5)
    
    ax[ax_nr][length-1].legend()
    fig.subplots_adjust(hspace=0.5)
    plt.tight_layout()

'''length = len(short_times) 
fig, ax = plt.subplots(2, len(short_times), sharey=True, facecolor='w', figsize = (length*5, 16))
plot_ts2(diff_mags_mean_list, ax_nr=0, plot_mean=False)
ax[0][length//2].set_title(f'Mean stacked time series for the differential magnitudes of {target} for {series_type} series in filter {filter_list[0]}')
plot_ts2(diff_mags_median_list, ax_nr=1)
ax[1][length//2].set_title(f'Median stacked time series for the differential magnitudes of {target} for {series_type} series in filter {filter_list[0]}')
plt.tight_layout()
plt.savefig(f'/home/finn/Pictures/Result Plots Bachelor/{series_type}_{target}_{filter_list[0][:1]}_diff_mags(both).png')'''
# Out:
# "length = len(short_times) \nfig, ax = plt.subplots(2, len(short_times), sharey=True, facecolor='w', figsize = (length*5, 16))\nplot_ts2(diff_mags_mean_list, ax_nr=0, plot_mean=False)\nax[0][length//2].set_title(f'Mean stacked time series for the differential magnitudes of {target} for {series_type} series in filter {filter_list[0]}')\nplot_ts2(diff_mags_median_list, ax_nr=1)\nax[1][length//2].set_title(f'Median stacked time series for the differential magnitudes of {target} for {series_type} series in filter {filter_list[0]}')\nplt.tight_layout()\nplt.savefig(f'/home/finn/Pictures/Result Plots Bachelor/{series_type}_{target}_{filter_list[0][:1]}_diff_mags(both).png')"

# %%
'''def plot_ts2(input_list, ax,  plot_mean=False):
    ax.tick_params(axis='x', rotation=45)
    ax.set_xlabel('Time [month-day hour:minute]')
    ax.set_ylabel('Differential magnitudes [mag]')
    for i in range (len(time_list)):
        ax.errorbar(short_times[i], input_list[i], yerr=np.std(input_list[i]), linestyle='none', marker='o', 
                    label='series from 23-' + short_times[i][0][:5] , capsize=2) #+ ' in Filter: ' + filter_list[i]

    if plot_mean == True:
        means_mean_stacked = [np.mean(diff_mags) for diff_mags in input_list]
        print(f'The mean of all {len(input_list)} series is: {round(np.mean(means_mean_stacked),4)} with std. of: {round(np.std(means_mean_stacked),4)}')
        ax.axhline(np.mean(means_mean_stacked), label=f'mean of all series', color='black', linestyle='--', alpha=0.5)
    ax.legend()
    plt.tight_layout()

fig, (ax1, ax2) = plt.subplots(2, len(short_times), figsize=(15, 15))
ax1.set_title(f'Mean stacked time series for the differential magnitudes of {target} for {series_type} series in filter {filter_list[0]}')
plot_ts2(diff_mags_mean_list, ax=ax1,  plot_mean=True) 
ax2.set_title(f'Median stacked time series for the differential magnitudes of {target} for {series_type} series in filter {filter_list[0]}')
plot_ts2(diff_mags_median_list, ax=ax2,  plot_mean=True) 
plt.savefig(f'/home/finn/Pictures/Result Plots Bachelor/{series_type}_{target}_{filter_list[0][:1]}_diff_mags(both).png')'''
# Out:
# "def plot_ts2(input_list, ax,  plot_mean=False):\n    ax.tick_params(axis='x', rotation=45)\n    ax.set_xlabel('Time [month-day hour:minute]')\n    ax.set_ylabel('Differential magnitudes [mag]')\n    for i in range (len(time_list)):\n        ax.errorbar(short_times[i], input_list[i], yerr=np.std(input_list[i]), linestyle='none', marker='o', \n                    label='series from 23-' + short_times[i][0][:5] , capsize=2) #+ ' in Filter: ' + filter_list[i]\n\n    if plot_mean == True:\n        means_mean_stacked = [np.mean(diff_mags) for diff_mags in input_list]\n        print(f'The mean of all {len(input_list)} series is: {round(np.mean(means_mean_stacked),4)} with std. of: {round(np.std(means_mean_stacked),4)}')\n        ax.axhline(np.mean(means_mean_stacked), label=f'mean of all series', color='black', linestyle='--', alpha=0.5)\n    ax.legend()\n    plt.tight_layout()\n\nfig, (ax1, ax2) = plt.subplots(2, len(short_times), figsize=(15, 15))\nax1.set_title(f'Mean stacked time serie
# ...

# %%
'''fig = plt.figure(figsize=(15,8))
plt.title(f'Time series for the differential magnitudes of {target} for {series_type} series (mean stacked)')
plot_ts(diff_mags_mean_list,  plot_mean=True) 
plt.savefig(f'/home/finn/Pictures/Result Plots Bachelor/{series_type}_{target}_{filter_list[0][:1]}_diff_mags(mean_stacked).png')


fig = plt.figure(figsize=(15,8))
plt.title(f'Time series for the differential magnitudes of {target} for {series_type} series (median stacked)')
plot_ts(diff_mags_median_list,  plot_mean=True) 
plt.savefig(f'/home/finn/Pictures/Result Plots Bachelor/{series_type}_{target}_{filter_list[0][:1]}_diff_mags(median_stacked).png')


plt.figure(figsize=(15,8))
plt.title(f'Time series for the background star magnitudes of {target} for {series_type} series')
plot_ts(mean_mag_mean_ft_list ) 
plot_ts(mean_mag_median_ft_list)
plt.savefig(f'/home/finn/Pictures/Result Plots Bachelor/{series_type}_{target}_{filter_list[0][:1]}_bkg_mags.png')


plt.figure(figsize=(15,8))
plt.title(f'Time series for the target star magnitudes of {target} for {series_type} series')
plot_ts(mag_mean_br_list) 
plot_ts(mag_median_br_list)
plt.savefig(f'/home/finn/Pictures/Result Plots Bachelor/{series_type}_{target}_{filter_list[0][:1]}_target_mags.png')'''
# Out:
# "fig = plt.figure(figsize=(15,8))\nplt.title(f'Time series for the differential magnitudes of {target} for {series_type} series (mean stacked)')\nplot_ts(diff_mags_mean_list,  plot_mean=True) \nplt.savefig(f'/home/finn/Pictures/Result Plots Bachelor/{series_type}_{target}_{filter_list[0][:1]}_diff_mags(mean_stacked).png')\n\n\nfig = plt.figure(figsize=(15,8))\nplt.title(f'Time series for the differential magnitudes of {target} for {series_type} series (median stacked)')\nplot_ts(diff_mags_median_list,  plot_mean=True) \nplt.savefig(f'/home/finn/Pictures/Result Plots Bachelor/{series_type}_{target}_{filter_list[0][:1]}_diff_mags(median_stacked).png')\n\n\nplt.figure(figsize=(15,8))\nplt.title(f'Time series for the background star magnitudes of {target} for {series_type} series')\nplot_ts(mean_mag_mean_ft_list ) \nplot_ts(mean_mag_median_ft_list)\nplt.savefig(f'/home/finn/Pictures/Result Plots Bachelor/{series_type}_{target}_{filter_list[0][:1]}_bkg_mags.png')\n\n\nplt.figure(figsize=(
# ...
