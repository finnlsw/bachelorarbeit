# %%
import numpy as np
import pandas as pd
from itertools import chain
import IPython.display
import matplotlib.pyplot as plt

# %%
#df1= dataframe from 04.09.23, df2 from 11.09 and df3 from 25.09 
df1=pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-04/results/results_2023-09-04_HIP_100587_B (Johnson)_30') # just change filename and run everthing below
df2=pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-11/results/results_2023-09-11_HIP100587_focused_B (Johnson)_40')
df3=pd.read_csv('/home/finn/visual_Studio_Code/data/2023-09-25/results/results_2023-09-25_HIP100587_B (Johnson)_40')

display(df1.tail())
display(df2.tail())
display(df3.tail())
# Out:
#      Unnamed: 0                       DR3Name     RAJ2000    DEJ2000  \
# 187         187  Gaia DR3 1862186189071964544  306.035420  31.997708
# 188         188  Gaia DR3 1862174644202786560  306.123405  31.987805
# 189         189  Gaia DR3 1862096819397471104  305.832927  31.999244
# 190         190  Gaia DR3 1862187048065451008  305.975655  31.992229
# 191         191  Gaia DR3 1862193748217511040  305.965057  32.190134
#
#          BPmag   e_BPmag      RPmag   e_RPmag       Gmag      Plx  ...  \
# 187  15.613221  0.003472  14.429175  0.004227  15.106946   1.4939  ...
# 188  10.496911  0.003170  10.092255  0.003907  10.367134   2.2467  ...
# 189  14.622296  0.003010  13.476235  0.003810  14.140223   0.3938  ...
# 190  12.808219  0.002838  12.226265  0.003792  12.586740   1.0204  ...
# 191   4.689272  0.003562   3.181613  0.004281   3.972560  12.2359  ...
#
#      Mag_Mean_Im_1  Mag_Mean_Im_2  Mag_Mean_Im_3  Mag_Mean_Im_4  \
# 187      -5.419437      -5.240637      -4.857716      -4.920697
# 188     -10.532642     -10.504157     -10.482854     -10.525855
# 189      -6.027172      -5.962051      -5.987456      -6.013883
# 190      -7.995491      -7.958754      -7.927021      -7.972246
# 191     -15.912622     -15.877471     -15.836625     -15.883051
#
#      Mag_Mean_Im_5  Mag_Median_Im_1  Mag_Median_Im_2  Mag_Median_Im_3  \
# 187      -5.241519        -5.597964        -5.207701        -4.863163
# 188     -10.473027       -10.531625       -10.500160       -10.478631
# 189      -5.920826        -6.041422        -5.985770        -5.992918
# 190      -7.934982        -7.996119        -7.956928        -7.923278
# 191     -15.841501       -15.907669       -15.875502       -15.833407
#
#      Mag_Median_Im_4  Mag_Median_Im_5
# 187        -4.894381        -5.075357
# 188       -10.525924       -10.474478
# 189        -6.013003        -5.913880
# 190        -7.973095        -7.932945
# 191       -15.877981       -15.833474
#
# [5 rows x 26 columns]
#      Unnamed: 0                       DR3Name     RAJ2000    DEJ2000  \
# 100         100  Gaia DR3 1862187907058841088  306.133825  32.016689
# 101         101  Gaia DR3 1862199898607988096  306.151000  32.291570
# 102         102  Gaia DR3 1862202235070351744  306.154131  32.340229
# 103         103  Gaia DR3 1862200757601460096  306.153142  32.320681
# 104         104  Gaia DR3 1862193748217511040  305.965057  32.190134
#
#          BPmag   e_BPmag      RPmag   e_RPmag       Gmag      Plx  ...  \
# 164       -15.677202       -15.647695       -15.452240       -15.311081
#
#      Mag_Median_Im_6  Mag_Median_Im_7
# 160        -5.494800        -5.501613
# 161        -5.851297        -5.830112
# 162        -5.109395        -3.739922
# 163        -6.512121        -3.527983
# 164       -15.692763       -15.646220
#
# [5 rows x 30 columns]

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['Unnamed: 0', 'DR3Name', 'RAJ2000', 'DEJ2000', 'BPmag', 'e_BPmag',
#        'RPmag', 'e_RPmag', 'Gmag', 'Plx', 'e_Plx', 'G-RP', 'BP-RP',
#        'Position Number', 'x', 'y', 'Mag_Mean_Im_1', 'Mag_Mean_Im_2',
#        'Mag_Mean_Im_3', 'Mag_Mean_Im_4', 'Mag_Mean_Im_5', 'Mag_Median_Im_1',
#        'Mag_Median_Im_2', 'Mag_Median_Im_3', 'Mag_Median_Im_4',
#        'Mag_Median_Im_5'],
#       dtype='object')
# Index(['Unnamed: 0', 'DR3Name', 'RAJ2000', 'DEJ2000', 'BPmag', 'e_BPmag',
#        'RPmag', 'e_RPmag', 'Gmag', 'Plx', 'e_Plx', 'G-RP', 'BP-RP',
#        'Position Number', 'x', 'y', 'Mag_Mean_Im_1', 'Mag_Mean_Im_2',
#        'Mag_Mean_Im_3', 'Mag_Mean_Im_4', 'Mag_Mean_Im_5', 'Mag_Median_Im_1',
#        'Mag_Median_Im_2', 'Mag_Median_Im_3', 'Mag_Median_Im_4',
#        'Mag_Median_Im_5'],
#       dtype='object')
# Index(['Unnamed: 0', 'DR3Name', 'RAJ2000', 'DEJ2000', 'BPmag', 'e_BPmag',
#        'RPmag', 'e_RPmag', 'Gmag', 'Plx', 'e_Plx', 'G-RP', 'BP-RP',
#        'Position Number', 'x', 'y', 'Mag_Mean_Im_1', 'Mag_Mean_Im_2',
#        'Mag_Mean_Im_3', 'Mag_Mean_Im_4', 'Mag_Mean_Im_5', 'Mag_Mean_Im_6',
#        'Mag_Mean_Im_7', 'Mag_Median_Im_1', 'Mag_Median_Im_2',
#        'Mag_Median_Im_3', 'Mag_Median_Im_4', 'Mag_Median_Im_5',
#        'Mag_Median_Im_6', 'Mag_Median_Im_7'],
#       dtype='object')

# %%
# Get unique 'DR3Name' values from each DataFrame
unique_names_df1 = df1['DR3Name'].unique()
unique_names_df2 = df2['DR3Name'].unique()
unique_names_df3 = df3['DR3Name'].unique()

# Find rows with same 'DR3Name' values across all DataFrames
common_names = set(unique_names_df1) & set(unique_names_df2) & set(unique_names_df3)

# Filter each DataFrame to keep only rows with 'DR3Name' present in common_names
fil_df1 = df1[df1['DR3Name'].isin(common_names)].copy()
fil_df2 = df2[df2['DR3Name'].isin(common_names)].copy()
fil_df3 = df3[df3['DR3Name'].isin(common_names)].copy()

# calc absolute magnitudes for next step
fil_df1['absolute Gmag'] = fil_df1['Gmag'] + 5*np.log10(fil_df1['Plx']/100)
fil_df2['absolute Gmag'] = fil_df2['Gmag'] + 5*np.log10(fil_df2['Plx']/100)
# 176        -4.778719        -4.858217        -4.795320        -4.681933
# 177        -6.123110        -6.023505        -6.040849        -6.044906
# 179        -4.943199        -5.035363        -5.054558        -5.110659
# 181        -6.143912        -6.145095        -6.137583        -6.167244
# 191       -15.907669       -15.875502       -15.833407       -15.877981
#
#      Mag_Median_Im_5  absolute Gmag
# 1          -4.700492       6.478088
# 7          -9.819006       0.398299
# 9          -6.954780       4.560732
# 14         -7.630315       3.669146
# 15         -4.923208       3.871356
# ..               ...            ...
# 176        -4.593772       3.987951
# 177        -5.983238       5.187615
# 179        -5.089303       2.926094
# 181        -6.101607       1.867815
# 191       -15.833474      -0.589260
#
# [81 rows x 27 columns]
#      Unnamed: 0                       DR3Name     RAJ2000    DEJ2000  \
# 2             2  Gaia DR3 2054250632554301184  305.758742  32.029744
# 3             3  Gaia DR3 2054250701273766912  305.796811  32.038514
# 5             5  Gaia DR3 1862097094275419520  305.798673  32.018778
# 6             6  Gaia DR3 2054251113591124224  305.824789  32.056846
# 7             7  Gaia DR3 1862097433551454848  305.833440  32.035812
# ..          ...                           ...         ...        ...
# 99           99  Gaia DR3 1862199692449546880  306.145036  32.263205
# 100         100  Gaia DR3 1862187907058841088  306.133825  32.016689
# 101         101  Gaia DR3 1862199898607988096  306.151000  32.291570
# 103         103  Gaia DR3 1862200757601460096  306.153142  32.320681
# 104         104  Gaia DR3 1862193748217511040  305.965057  32.190134
#
#          BPmag   e_BPmag      RPmag   e_RPmag       Gmag      Plx  ...  \
# 2    15.213050  0.003053  14.143268  0.003865  14.767079   0.8974  ...
# 3    15.224984  0.003489  14.145172  0.003989  14.766366   1.3980  ...
# 5    15.412912  0.003110  13.870637  0.003860  14.703901   0.4410  ...
# 6    14.956777  0.003154  13.894425  0.003830  14.508298   1.1526  ...
# 7    12.517401  0.002838  11.698488  0.003795  12.187820   2.1094  ...
# ..         ...       ...        ...       ...        ...      ...  ...
# 99   14.389542  0.002861  13.571593  0.003834  14.064461   1.0952  ...
# 100   9.365703  0.002817   9.154440  0.003789   9.297263   3.7787  ...
# 101  14.610340  0.003038  13.714520  0.003888  14.247213   1.3509  ...
# 103  13.764835  0.003004  12.860876  0.004344  13.420399   1.6907  ...
# 104   4.689272  0.003562   3.181613  0.004281   3.972560  12.2359  ...
#
#      Mag_Mean_Im_2  Mag_Mean_Im_3  Mag_Mean_Im_4  Mag_Mean_Im_5  \
# 2        -5.268067      -5.232518      -5.196750      -5.057044
# 3        -5.138360      -5.197346      -5.191968      -5.114993
# 5        -4.881939      -4.993485      -5.066576      -4.940966
# 6        -5.448532      -5.442774      -5.469964      -5.312881
# 7        -8.102120      -8.100476      -8.073175      -7.965839
# ..             ...            ...            ...            ...
# 99       -6.237182      -6.234087      -6.213299      -6.158615
# 100     -11.586127     -11.580025     -11.557610     -11.476047
# 101      -6.183441      -6.199712      -6.198173      -6.073802
# 103      -6.901631      -6.908309      -6.912228      -6.819142
# 104     -15.301844     -15.340776     -15.316084     -15.258826
#
#      Mag_Median_Im_1  Mag_Median_Im_2  Mag_Median_Im_3  Mag_Median_Im_4  \
# 2          -5.285011        -5.356247        -5.330675        -5.264081
# 3          -5.128465        -5.172452        -5.222847        -5.218331
# 5          -5.006405        -4.946290        -5.058247        -5.141043
# 6          -5.481001        -5.447549        -5.410934        -5.406839
# 7          -8.136012        -8.128167        -8.135761        -8.104285
# ..               ...              ...              ...              ...
# 99         -6.231866        -6.219591        -6.219220        -6.206865
# 100       -11.695741       -11.713652       -11.713068       -11.697894
# 101        -6.128716        -6.152550        -6.202765        -6.181226
# 103        -6.885678        -6.903735        -6.928408        -6.934725
# 104       -15.384065       -15.368116       -15.398606       -15.382551
#
#      Mag_Median_Im_5  absolute Gmag
# 2          -5.125619       4.532009
# 3          -5.176711       5.493902
# 5          -4.902209       2.926094
# 6          -5.389095       4.816691
# 7          -8.002867       3.808615
# ..               ...            ...
# 99         -6.152873       4.261928
# 100       -11.615045       2.183975
# 101        -6.098737       4.900329
# 103        -6.849664       4.560732
# 104       -15.324036      -0.589260
#
# [81 rows x 27 columns]
#      Unnamed: 0                       DR3Name     RAJ2000    DEJ2000  \
# 2             2  Gaia DR3 2054250632554301184  305.758742  32.029744
# 9             9  Gaia DR3 2054250701273766912  305.796811  32.038514
# 10           10  Gaia DR3 1862097094275419520  305.798673  32.018778
# 14           14  Gaia DR3 2054251113591124224  305.824789  32.056846
# 15           15  Gaia DR3 1862097433551454848  305.833440  32.035812
# ..          ...                           ...         ...        ...
# 149         149  Gaia DR3 1862199692449542656  306.142217  32.249645
# 150         150  Gaia DR3 1862199692449546880  306.145036  32.263205
# 151         151  Gaia DR3 1862199898607988096  306.151000  32.291570
# 152         152  Gaia DR3 1862200757601460096  306.153142  32.320681
# 164         164  Gaia DR3 1862193748217511040  305.965057  32.190134
#
#          BPmag   e_BPmag      RPmag   e_RPmag       Gmag      Plx  ...  \
# 2    15.213050  0.003053  14.143268  0.003865  14.767079   0.8974  ...
# 9    15.224984  0.003489  14.145172  0.003989  14.766366   1.3980  ...
# 10   15.412912  0.003110  13.870637  0.003860  14.703901   0.4410  ...
# 14   14.956777  0.003154  13.894425  0.003830  14.508298   1.1526  ...
# 15   12.517401  0.002838  11.698488  0.003795  12.187820   2.1094  ...
# ..         ...       ...        ...       ...        ...      ...  ...
# 149  13.691182  0.003016  11.858677  0.003845  12.795085   0.5768  ...
# 150  14.389542  0.002861  13.571593  0.003834  14.064461   1.0952  ...
# 151  14.610340  0.003038  13.714520  0.003888  14.247213   1.3509  ...
# 152  13.764835  0.003004  12.860876  0.004344  13.420399   1.6907  ...
# 164   4.689272  0.003562   3.181613  0.004281   3.972560  12.2359  ...
#
#      Mag_Mean_Im_6  Mag_Mean_Im_7  Mag_Median_Im_1  Mag_Median_Im_2  \
# 2        -5.540011      -5.297626         0.814487        -5.387476
# 9        -5.321152      -5.285636        -1.426101        -5.300345
# 10       -5.012026      -4.972445        -2.131427        -4.949836
# 14       -5.479435      -5.450643        -6.879369        -5.534250
# 15       -8.178799      -8.131719        -1.463773        -8.167665
# ..             ...            ...              ...              ...
# 149      -6.286284      -6.253807        -0.744827        -6.221341
# 150      -6.315388      -6.262741        -0.904239        -6.242211
# 151      -6.062252      -6.046261        -1.616709        -6.024098
# 152      -6.920324      -6.908712        -2.151229        -6.877168
# 164     -15.708217     -15.661278       -15.663425       -15.677202
#
#      Mag_Median_Im_3  Mag_Median_Im_4  Mag_Median_Im_5  Mag_Median_Im_6  \
# 2          -5.227464        -5.039057        -4.941523        -5.379833
# 9          -5.217979        -5.036341        -4.836422        -5.330227
# 10         -4.931422        -4.766353        -4.717572        -5.016992
# 14         -5.448006        -5.263939        -5.112730        -5.471841
# 15         -8.128174        -7.904553        -7.781894        -8.175030
# ..               ...              ...              ...              ...
# 149        -6.220383        -6.033451        -5.945998        -6.290867
# 150        -6.268629        -6.062959        -5.950514        -6.313831
# 151        -6.020134        -5.870068        -5.699920        -6.054750
# 152        -6.881985        -6.735980        -6.553158        -6.920767
# 164       -15.647695       -15.452240       -15.311081       -15.692763
#
#      Mag_Median_Im_7  absolute Gmag
# 2          -5.291734       4.532009
# 9          -5.285525       5.493902
# 10         -4.947694       2.926094
# 14         -5.472534       4.816691
# 15         -8.125258       3.808615
# ..               ...            ...
# 149        -6.246510       1.600211
# 150        -6.264645       4.261928
# 151        -6.046089       4.900329
# 152        -6.900018       4.560732
# 164       -15.646220      -0.589260
#
# [81 rows x 31 columns]

# %%
#import cns5 data for comparrison
df_cns5 = pd.read_csv('/home/finn/visual_Studio_Code/data/CNS5_data.csv')
df_cns5 = df_cns5.dropna() # remove all NaN values
df_cns5['absolute Gmag CNS5'] = df_cns5['g_mag'] + 5*np.log10(df_cns5['parallax']/100)
#display(df_cns5)

fig, axs = plt.subplots(1, 2, figsize=(15, 6))

axs[0].scatter(fil_df1['G-RP'], fil_df1['absolute Gmag'], alpha=0.5, label='Stars FOV HIP100587')
axs[0].scatter(fil_df1['G-RP'][-1:], fil_df1['absolute Gmag'][-1:], alpha=0.5, color='yellow', label='HIP100587')
axs[0].scatter(df_cns5['g_rp_resulting'], df_cns5['absolute Gmag CNS5'], alpha=0.2, color='red', s=1,label='CNS5 stars')
axs[0].invert_yaxis()  # Invert y-axis for the left plot
axs[0].set_xlabel('G-RP [mag]')
axs[0].set_ylabel(r'$M_G$ [mag]')
axs[0].legend()
axs[0].set_title(f'colour-absolute-magnitude diagram for the field of HIP 100587 (containing {len(df1)-1} stars)')


axs[1].scatter(fil_df1['BP-RP'][:-1], fil_df1['absolute Gmag'][:-1], alpha=0.5,   s=100.0,label='Stars FOV HIP100587')
#axs[1].scatter(fil_df2['BP-RP'][:-1], fil_df2['absolute Gmag'][:-1], alpha=0.5, color='green', s=50.0,label='Stars FOV HIP100587')
#axs[1].scatter(fil_df3['BP-RP'][:-1], fil_df3['absolute Gmag'][:-1], alpha=0.5, color='yellow',s=20.0,label='Stars FOV HIP100587')
axs[1].scatter(fil_df1['BP-RP'][-1:], fil_df1['absolute Gmag'][-1:], alpha=0.5, color='yellow', s=100, label='HIP100587')
axs[1].legend()
axs[1].invert_yaxis()
axs[1].set_xlabel('BP-RP [mag]')
axs[1].set_ylabel(r'$M_G$ [mag]')

plt.tight_layout()

# %%
def get_mag_lists(df):
    df_ft = df.iloc[:-1,:] # all rows expept last one (bright star), all columns
    #display(df_ft)
    df_br = df.iloc[-1:,:] #just last row
    #display(df_br)

    mag_mean_columns_ft = [col for col in df_ft.columns if 'Mag_Mean_Im' in col]
    mag_mean_ft = df_ft[mag_mean_columns_ft].values.T.tolist()
    mean_mag_mean_ft = [np.mean(sublist) for sublist in mag_mean_ft]

    mag_median_columns_ft = [col for col in df_ft.columns if 'Mag_Median_Im' in col]
    mag_median_ft = df_ft[mag_median_columns_ft].values.T.tolist()
    mean_mag_median_ft = [np.mean(sublist) for sublist in mag_median_ft]

    mag_mean_columns_br = [col for col in df_br.columns if 'Mag_Mean_Im' in col]
    mag_mean_br = df_br[mag_mean_columns_br].values.T.tolist() 
    mag_mean_br = list(chain.from_iterable(mag_mean_br)) #to remove inner brackets i.e. [[.],[.],[.]] -> [.,.,.]

    mag_median_columns_br = [col for col in df_br.columns if 'Mag_Median_Im' in col]
    mag_median_br = df_br[mag_median_columns_br].values.T.tolist()
    mag_median_br = list(chain.from_iterable(mag_median_br))

    print(mean_mag_mean_ft)
    print(mean_mag_median_ft)
    print(mag_mean_br)
    print(mag_median_br)
    print('')
    return mean_mag_mean_ft, mean_mag_median_ft, mag_mean_br, mag_median_br

mean_mag_mean_ft1, mean_mag_median_ft1, mag_mean_br1, mag_median_br1 = get_mag_lists(fil_df1)
mean_mag_mean_ft2, mean_mag_median_ft2, mag_mean_br2, mag_median_br2 = get_mag_lists(fil_df2)
mean_mag_mean_ft3, mean_mag_median_ft3, mag_mean_br3, mag_median_br3 = get_mag_lists(fil_df3)
# Out:
# [-6.591067474957887, -6.571670213096101, -6.542278238290635, -6.579851826701146, -6.543668541791109]
# [-6.588141579049004, -6.570302336457322, -6.542846701266049, -6.577959023485735, -6.542656477402744]
# [-15.912622396096346, -15.877471095839065, -15.83662526346993, -15.88305103701317, -15.841501384178214]
# [-15.907668688317704, -15.875502003681564, -15.833407345068398, -15.877980546064002, -15.833473681744312]
#
# [-6.574202889803186, -6.560188767634268, -6.574365070123003, -6.560329749439925, -6.45647441218396]
# [-6.580254517190271, -6.575732826123366, -6.566707310411641, -6.551526515336841, -6.4550828621371155]
# [-15.324888636002392, -15.301843752876447, -15.34077626154608, -15.31608385549837, -15.258826054690475]
# [-15.384065114726582, -15.368115515106629, -15.398606239711247, -15.382551377792282, -15.324035848867869]
#
# [-1.3917311193119548, -6.57872828183763, -6.548864610720526, -6.361180195192833, -6.327183411458913, -6.595636900991269, -6.5664604794267465]
# [-1.3389606183490639, -6.5701162502921, -6.5492549892848855, -6.355109875233206, -6.214848873222203, -6.59275876528387, -6.560618824473447]
# [-15.67528258096557, -15.687385527122988, -15.65358640440042, -15.466526211580131, -15.407210474279722, -15.708217046456278, -15.661278111426013]
# [-15.663425480302838, -15.677201851152937, -15.647694947139277, -15.452239565612189, -15.31108147077805, -15.69276346560083, -15.646220356282832]

# %%
# ONLY FOR 25.09 HIP100587 ls B
mean_mag_mean_ft3 = mean_mag_mean_ft3[1:]
mean_mag_median_ft3 = mean_mag_median_ft3[1:]
mag_mean_br3 = mag_mean_br3[1:]
mag_median_br3 = mag_median_br3[1:]

# %%
'''
def calc_results(mag_ft_mean, mag_br_mean, mag_ft_median, mag_br_median):
    diff_mags_mean = [m_br-m_ft for m_br,m_ft in zip(mag_br_mean, mag_ft_mean)]
    print(f'The differential Magnitudes are: {diff_mags_mean}')
    print(f'The Mean of the diff Mags is: {round(np.mean(diff_mags_mean),5)} +- {round(np.std(diff_mags_mean),5)}')
    print(f'The std for target is: {round(np.std(mag_br_mean),5)} and for the bkg stars: {round(np.std(mag_ft_mean),5)}')
    print('')
    return diff_mags_mean
'''

def calc_results(mag_ft_mean, mag_br_mean, mag_ft_median, mag_br_median):
    diff_mags_mean = [m_br - m_ft for m_br, m_ft in zip(mag_br_mean, mag_ft_mean)]
    diff_mags_median = [m_br - m_ft for m_br, m_ft in zip(mag_br_median, mag_ft_median)]

    #print(f'The differential Magnitudes for mean values are: {diff_mags_mean}')
    print(f'The Mean of the diff Mags (mean values) is: {round(np.mean(diff_mags_mean), 5)} +- {round(np.std(diff_mags_mean), 5)}')
    #print(f'The std for target (mean values) is: {round(np.std(mag_br_mean), 5)} and for the bkg stars (mean values): {round(np.std(mag_ft_mean), 5)}')
    print('')
    #print(f'The differential Magnitudes for median values are: {diff_mags_median}')
    print(f'The Mean of the diff Mags (median values) is: {round(np.mean(diff_mags_median), 5)} +- {round(np.std(diff_mags_median), 5)}')
    #print(f'The std for target (median values) is: {round(np.std(mag_br_median), 5)} and for the bkg stars (median values): {round(np.std(mag_ft_median), 5)}')
    print('')
    return diff_mags_mean, diff_mags_median

# Calling the function with the additional arguments for the names
diff_mags_mean, diff_mags_median = calc_results(mean_mag_mean_ft1, mag_mean_br1, mean_mag_median_ft1, mag_median_br1)
diff_mags_mean, diff_mags_median = calc_results(mean_mag_mean_ft2, mag_mean_br2, mean_mag_median_ft2, mag_median_br2)
diff_mags_mean, diff_mags_median = calc_results(mean_mag_mean_ft3, mag_mean_br3, mean_mag_median_ft3, mag_median_br3)
# Out:
# The Mean of the diff Mags (mean values) is: -9.30455 +- 0.0094
#
# The Mean of the diff Mags (median values) is: -9.30123 +- 0.01072
#
# The Mean of the diff Mags (mean values) is: -8.76337 +- 0.02107
#
# The Mean of the diff Mags (median values) is: -8.82561 +- 0.02656
#
# The Mean of the diff Mags (mean values) is: -9.10102 +- 0.01083
#
# The Mean of the diff Mags (median values) is: -9.09742 +- 0.00635
